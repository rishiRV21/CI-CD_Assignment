# %% [markdown]
# # CI/CD Assignment

# %% [markdown]
# **1. Continuous Integration (CI)**
#
# **Task 1:** Set Up a CI Pipeline
#
# **Objective:** Set up a basic CI pipeline that builds a project automatically whenever new code is pushed.
#
# **Tools:** GitHub Actions, Jenkins, GitLab CI, or CircleCI
#
# **Instructions:**
#
# *    Create a simple application (use Node.js, Python, or Java)
# *    Set up a repository on GitHub or GitLab
#
#
# *    Configure a CI tool to automatically build the application whenever new code is pushed to the repository
# *   Document each step with screenshots showing the pipeline running

# %%
# app.py
def add(a, b):
    return a + b

# %% [markdown]
# 1. Created a GitHub repository named "CI-CD_python_app"
# 2. Uploaded app.py file
# 3. Enabled GitHub Actions from repository settings

# %% [markdown]
# Task 1 Completed:
# - Created a public GitHub repository named CI-CD_python_app
# - Added README.md file
# - Added app.py with a Python function
# - Committed the code successfully to main branch
# - Repository link submitted for evaluation
# ![Screenshot 2025-12-20 200422.png](data:image/png;base64,...)

# %% [markdown]
# **2.** **Jenkins**
#
# **Task 2:** Automated Build with Jenkins
#
# **Objective:** Install Jenkins and configure an automated build job.
#
# **Tools:** Jenkins, Docker (optional)
#
# **Instructions:**
#
# *   Install Jenkins on your local machine or use a cloud platform (like AWS, Azure)
# *   Set up a simple job that clones a Git repository and builds the project (e.g., a Java project using Maven or a
# Node.js project)
# *   Set up a trigger to run the job automatically when new code is pushed to the repository
# repository List item
# *   Take screenshots of the Jenkins job and the build logs to demonstrate success.

# %% [markdown]
# - I implemented a CI pipeline using Jenkins. Jenkins pulls source code from GitHub, builds it automatically, and reports build status. The build initially failed due to branch mismatch, which I fixed by updating the branch from master to main.![Screenshot 2025-12-22 231957.png](data:image/png;base64,...)

# %% [markdown]
# **3. Testing Frameworks and Practices**
#
# **Task 3:** Write Unit Tests for an Application
#
# **Objective:** Write unit tests for a simple application and integrate them into a CI pipeline.
#
# **Tools:** Jest (JavaScript), JUnit (Java), pytest (Python)
#
# **Instructions:**
# *   Create a small application (e.g., a calculator, to-do list, or API)
# *  Write unit tests for the core functions (e.g., add, delete, or update functions)
# *   Integrate these tests into a CI pipeline using GitHub Actions, Jenkins, or GitLab CI
# *   Document your work with screenshots showing the tests running in the CI pipeline.

# %% [markdown]
# - A simple Python calculator application was created. Unit tests were written using pytest to test core functions like addition, subtraction, multiplication, and division. Jenkins was used to create a CI pipeline that automatically pulls code from GitHub, installs dependencies in a virtual environment, and runs unit tests. The build succeeds only if all tests pass. Screenshots of successful builds are attached.![Screenshot 2025-12-23 001611.png](data:image/png;base64,...)

# %% [markdown]
# **4. Integration Testing**
#
# **Task 4:** Set Up Integration Testing for an API
#
# **Objective:** Write integration tests for a REST API and automate them in a CI pipeline.
#
# **Tools:** Postman, Newman, or Selenium (for web UI testing)
#
# **Instructions:**
#
# *  Create a simple REST API (using Node.js, Python Flask, or Java Spring Boot)
# *    Write integration tests to check the interaction between different components (e.g., database and API)
# *    Set up the tests to run automatically in a Jenkins or GitLab CI pipeline after each deployment to a staging environment
# *   Capture screenshots showing successful test execution.

# %% [markdown]
# - A simple Python Flask application was created with REST API endpoints.
# Unit tests were written using the pytest framework to validate application functionality.
# A Continuous Integration (CI) pipeline was implemented using GitHub Actions, which automatically installs dependencies and runs unit tests on every push to the repository.
# The CI workflow executed successfully, ensuring code quality and reliability through automated testing.![image.png](data:image/png;base64,...)
#
#
# ![Screenshot 2025-12-23 230354.png](data:image/png;base64,...)

# %% [markdown]
# **5. Performance Testing**
#
# **Task 5**:
# Automate Performance Testing in a CI/CD Pipeline italicized text
#
# **Objective**: Automate performance testing using tools like Apache JMeter or K6.
#
# **Tools:** JMeter, K6, Jenkins, or GitLab CI
#
# **Instructions:**
# *  Create a simple web application (or use an existing one)
# *    Write a JMeter or K6 test script to load test the application
# *    Automate the performance test in your CI/CD pipeline to run after every build
# * Provide screenshots showing the performance results and graphs from the tool.

# %% [markdown]
# **Performance Testing Using K6 in CI/CD Pipeline**
#
# **Objective:**
# To automate performance testing of a web application using K6 in a CI/CD pipeline.
#
# **Tools Used:**
#
# *   GitHub Actions
# *   K6
# *   Python Flask Web Application
#
#
# **Description:**
# A simple Python web application was created and stored in a GitHub repository. A K6 performance test script was written to simulate multiple users accessing the application. The test script was integrated into the CI/CD pipeline using GitHub Actions so that it runs automatically after every code push.
#
# **Result:**
# The performance test executed successfully after each build. K6 generated performance metrics such as request duration, request count, and success rate, confirming the application's performance under load.
#
# **Conclusion:**
# Automating performance testing in CI/CD helps identify performance issues early and ensures application stability before deployment.![Screenshot 2025-12-24 203616.png](data:image/png;base64,...)

# %% [markdown]
# **6. Security Testing**
#
# **Task 6:** Implement Basic Security Testing in a CI Pipeline
#
# **Objective:** Integrate security testing into the CI pipeline using tools like OWASP ZAP or SonarQube.
#
# **Tools:** OWASP ZAP, SonarQube, Jenkins, GitLab CI
#
# **Instructions:**
# *   Set up a simple web application
# *   Use OWASP ZAP to scan the application for vulnerabilities or use SonarQube for static code analysis
# *  Automate these tests in the CI pipeline to run every time code is pushed
# *  Take screenshots showing any vulnerabilities or issues detected by the tool.
# ![Screenshot 2025-12-24 205246.png](data:image/png;base64,...)

# %% [markdown]
# **7. Continuous Deployment (CD)**
#
# **Task 7:** Automate Deployment to Staging Environment
#
# **Objective:** Automate the deployment of an application to a staging environment after a successful build and
# test.
#
# **Tools:** Jenkins, AWS CodeDeploy, Docker, Kubernetes
#
# **Instructions:**
# *   Create a simple application (Node.js, Python, or Java)
# *  Set up a CI pipeline that builds the application, runs tests, and deploys it to a staging environment (using AWS, Docker, or Kubernetes)
# *    Document the pipeline setup, and take screenshots of the deployment logs
# *    Ensure the application is live and accessible from the staging environment

# %% [markdown]
# - A Continuous Deployment pipeline was implemented using GitHub Actions and Docker. After successful code push and testing, the application is automatically built into a Docker image and deployed to a staging environment. The workflow ensures reliable, fast, and automated deployments without manual intervention. The successful deployment was verified through GitHub Actions logs.
#
# ![Screenshot 2025-12-24 215724.png](data:image/png;base64,...)
#
#
#
# ![Screenshot 2025-12-24 215857.png](data:image/png;base64,...)
